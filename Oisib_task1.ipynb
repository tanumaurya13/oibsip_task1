# %% [markdown]
# <a href="https://colab.research.google.com/github/tanumaurya13/oibsip_task1/blob/main/Oisib_task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Iris Flower Classification

# %%
# Import Packages

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# %matplotlib inline

# %%
columns = ['Sepal length', 'Sepal width', 'Petal length', 'Petal width', 'Class_labels']
# Loading data
df = pd.read_csv('iris.data', names=columns)
df.head(150)
# Out:
#      Sepal length  Sepal width  Petal length  Petal width    Class_labels
# 1             5.1          3.5           1.4          0.2     Iris-setosa
# 2             4.9          3.0           1.4          0.2     Iris-setosa
# 3             4.7          3.2           1.3          0.2     Iris-setosa
# 4             4.6          3.1           1.5          0.2     Iris-setosa
# 5             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 146           6.7          3.0           5.2          2.3  Iris-virginica
# 147           6.3          2.5           5.0          1.9  Iris-virginica
# 148           6.5          3.0           5.2          2.0  Iris-virginica
# 149           6.2          3.4           5.4          2.3  Iris-virginica
# 150           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.describe()
# Out:
#        Sepal length  Sepal width  Petal length  Petal width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
sns.scatterplot(x='Sepal length',y='Sepal width',hue='Class_labels', data=df)
# Add labels and title
plt.xlabel('sepal length')
plt.ylabel('Sepal width')
plt.title('Iris dataset - Sepal length vs. Sepal width')
# Show the plot
plt.show()

# %%
sns.scatterplot(x='Petal length',y='Petal width',hue='Class_labels', data=df)
# Add labels and title
plt.xlabel('Petal length')
plt.ylabel('Petal width')
plt.title('Iris dataset - Petal length vs. Petal width')
# Show the plot
plt.show()

# %%
fig,((ax1,ax2),(ax3,ax4)) = plt.subplots(2,2, figsize=(10, 10))
sns.violinplot(x="Class_labels", y="Sepal length", data=df, ax=ax1)
sns.violinplot(x="Class_labels", y="Sepal width", data=df, ax=ax2)
sns.violinplot(x="Class_labels", y="Petal length", data=df, ax=ax3)
sns.violinplot(x="Class_labels", y="Petal width", data=df, ax=ax4)
# Out:
# <Axes: xlabel='Class_labels', ylabel='Petal width'>

# %%
# Visualize the whole dataset
sns.pairplot(df, hue='Class_labels')

# %%
# Separate features and target
data = df.values
X = data[:,0:4]
print(X)
# Out:
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.0 1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.0 3.6 1.4 0.2]
#  [5.4 3.9 1.7 0.4]
#  [4.6 3.4 1.4 0.3]
#  [5.0 3.4 1.5 0.2]
#  [4.4 2.9 1.4 0.2]
#  [4.9 3.1 1.5 0.1]
#  [5.4 3.7 1.5 0.2]
#  [4.8 3.4 1.6 0.2]
#  [4.8 3.0 1.4 0.1]
#  [4.3 3.0 1.1 0.1]
#  [5.8 4.0 1.2 0.2]
#  [5.7 4.4 1.5 0.4]
#  [5.4 3.9 1.3 0.4]
#  [5.1 3.5 1.4 0.3]
#  [5.7 3.8 1.7 0.3]
#  [5.1 3.8 1.5 0.3]
#  [5.4 3.4 1.7 0.2]
#  [5.1 3.7 1.5 0.4]
#  [4.6 3.6 1.0 0.2]
#  [5.1 3.3 1.7 0.5]
#  [4.8 3.4 1.9 0.2]
#  [5.0 3.0 1.6 0.2]
#  [5.0 3.4 1.6 0.4]
#  [5.2 3.5 1.5 0.2]
#  [5.2 3.4 1.4 0.2]
#  [4.7 3.2 1.6 0.2]
#  [4.8 3.1 1.6 0.2]
#  [5.4 3.4 1.5 0.4]
#  [5.2 4.1 1.5 0.1]
#  [5.5 4.2 1.4 0.2]
#  [4.9 3.1 1.5 0.1]
#  [5.0 3.2 1.2 0.2]
#  [5.5 3.5 1.3 0.2]
#  [4.9 3.1 1.5 0.1]
#  [4.4 3.0 1.3 0.2]
#  [5.1 3.4 1.5 0.2]
#  [5.0 3.5 1.3 0.3]
#  [4.5 2.3 1.3 0.3]
#  [4.4 3.2 1.3 0.2]
#  [5.0 3.5 1.6 0.6]
#  [5.1 3.8 1.9 0.4]
#  [4.8 3.0 1.4 0.3]
#  [5.1 3.8 1.6 0.2]
# ...

# %%
Y = data[:,4]
print(Y)
# Out:
# ['Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
# ...

# %%
# Split the data to train and test dataset.
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)
print(X_test)
# Out:
# [[6.1 3.0 4.9 1.8]
#  [6.4 2.8 5.6 2.1]
#  [7.7 3.0 6.1 2.3]
#  [5.5 2.3 4.0 1.3]
#  [5.8 2.7 5.1 1.9]
#  [6.7 3.3 5.7 2.5]
#  [7.6 3.0 6.6 2.1]
#  [5.5 2.5 4.0 1.3]
#  [5.2 3.4 1.4 0.2]
#  [6.9 3.1 5.1 2.3]
#  [4.9 2.5 4.5 1.7]
#  [5.0 3.5 1.3 0.3]
#  [6.4 2.7 5.3 1.9]
#  [6.2 2.8 4.8 1.8]
#  [6.7 3.0 5.0 1.7]
#  [7.2 3.6 6.1 2.5]
#  [7.0 3.2 4.7 1.4]
#  [5.0 3.3 1.4 0.2]
#  [6.9 3.2 5.7 2.3]
#  [5.7 2.9 4.2 1.3]
#  [6.3 2.7 4.9 1.8]
#  [5.2 3.5 1.5 0.2]
#  [6.3 3.3 6.0 2.5]
#  [6.2 2.9 4.3 1.3]
#  [6.8 3.0 5.5 2.1]
#  [6.0 3.0 4.8 1.8]
#  [6.4 3.2 4.5 1.5]
#  [5.0 3.4 1.6 0.4]
#  [6.2 3.4 5.4 2.3]
#  [6.4 2.9 4.3 1.3]]

# %% [markdown]
# 1) SVC

# %%
# Support vector machine algorithm
from sklearn.svm import SVC

mdsvc = SVC()
mdsvc.fit(X_train, y_train)
# Out:
# SVC()

# %%
# Predict from the test dataset
prediction1 = mdsvc.predict(X_test)

# Calculate the accuracy
from sklearn.metrics import accuracy_score
accuracy_score(y_test, prediction1)*100
# Out:
# 80.0

# %% [markdown]
# 2) Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
mdlr=LogisticRegression()
mdlr.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
prediction2=mdlr.predict(X_test)
# Calculate the accuracy
from sklearn.metrics import accuracy_score
accuracy_score(y_test, prediction2)*100
# Out:
# 86.66666666666667

# %% [markdown]
# 3)Random forest

# %%
from sklearn.ensemble import RandomForestClassifier
mdrf=RandomForestClassifier()
mdrf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
prediction3=mdrf.predict(X_test)
# Calculate the accuracy
from sklearn.metrics import accuracy_score
accuracy_score(y_test, prediction3)*100
# Out:
# 86.66666666666667

# %% [markdown]
# 4) KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
mdknn=KNeighborsClassifier()
mdknn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
prediction4=mdknn.predict(X_test)
# Calculate the accuracy
from sklearn.metrics import accuracy_score
accuracy_score(y_test, prediction4)*100
# Out:
# 83.33333333333334

# %% [markdown]
# Inputting random data for checking predictions

# %%
# A detailed classification report
from sklearn.metrics import classification_report
print(classification_report(y_test, prediction2))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00         5
# Iris-versicolor       0.70      0.88      0.78         8
#  Iris-virginica       0.93      0.82      0.87        17
#
#        accuracy                           0.87        30
#       macro avg       0.88      0.90      0.88        30
#    weighted avg       0.88      0.87      0.87        30

# %%
X_new = np.array([[3, 2, 1, 0.2], [  4.9, 2.2, 3.8, 1.1 ], [  5.3, 2.5, 4.6, 1.9 ]])
#Prediction of the species from the input vector
prediction = mdlr.predict(X_new)
print("Prediction of Species: {}".format(prediction))
# Out:
# Prediction of Species: ['Iris-setosa' 'Iris-versicolor' 'Iris-versicolor']
